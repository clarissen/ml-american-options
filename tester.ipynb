# %%
import data_optiondx as data_odx

df = data_odx.SPY_jan23_eod_df_raw

df_calls = data_odx.df_calls

df_calls
# Out:
#       [QUOTE_DATE]  [UNDERLYING_LAST] [EXPIRE_DATE]   [DTE]  [C_DELTA]  \
# 0       2023-01-03             380.82    2023-01-03     0.0    0.96551
# 1       2023-01-03             380.82    2023-01-03     0.0    0.96015
# 2       2023-01-03             380.82    2023-01-03     0.0    0.95788
# 3       2023-01-03             380.82    2023-01-03     0.0    0.96337
# 4       2023-01-03             380.82    2023-01-03     0.0    0.95600
# ...            ...                ...           ...     ...        ...
# 78916   2023-01-31             406.44    2025-12-19  1053.0    0.09236
# 78917   2023-01-31             406.44    2025-12-19  1053.0    0.08463
# 78918   2023-01-31             406.44    2025-12-19  1053.0    0.08428
# 78919   2023-01-31             406.44    2025-12-19  1053.0    0.07248
# 78920   2023-01-31             406.44    2025-12-19  1053.0    0.07308
#
#        [C_GAMMA]  [C_VEGA]  [C_THETA]  [C_RHO]   [C_IV]  [C_VOLUME]  [C_LAST]  \
# ...

# %%
import data

df, features, target = data.get_data("calls")

df
# Out:
#        Stock Price (S)  Strike Price (K)  Dividend Yield (q)  \
# 0                  100        107.946863            0.043112
# 1                  100         93.129280            0.057690
# 2                  100        101.884856            0.038422
# 3                  100        105.139485            0.038146
# 4                  100        107.367845            0.053985
# ...                ...               ...                 ...
# 99995              100        108.180902            0.045472
# 99996              100        106.423015            0.034393
# 99997              100         95.594475            0.036404
# 99998              100         96.015746            0.023868
# 99999              100         95.795485            0.025726
#
#        Risk-Free Rate (r)  Implied Volatility (v)  Time to Expiry (T)  \
# 0                0.021989                0.211220            0.876063
# 1                0.046476                0.255871            1.301628
# ...

# %%
df_calls = data_odx.df_calls
df_puts = data_odx.df_puts

# %%
df_calls
# Out:
#       [QUOTE_DATE]  [UNDERLYING_LAST] [EXPIRE_DATE]   [DTE]  [C_DELTA]  \
# 0       2023-01-03             380.82    2023-01-03     0.0    0.96551
# 1       2023-01-03             380.82    2023-01-03     0.0    0.96015
# 2       2023-01-03             380.82    2023-01-03     0.0    0.95788
# 3       2023-01-03             380.82    2023-01-03     0.0    0.96337
# 4       2023-01-03             380.82    2023-01-03     0.0    0.95600
# ...            ...                ...           ...     ...        ...
# 78916   2023-01-31             406.44    2025-12-19  1053.0    0.09236
# 78917   2023-01-31             406.44    2025-12-19  1053.0    0.08463
# 78918   2023-01-31             406.44    2025-12-19  1053.0    0.08428
# 78919   2023-01-31             406.44    2025-12-19  1053.0    0.07248
# 78920   2023-01-31             406.44    2025-12-19  1053.0    0.07308
#
#        [C_GAMMA]  [C_VEGA]  [C_THETA]  [C_RHO]   [C_IV]  [C_VOLUME]  [C_LAST]  \
# ...

# %%
df_puts
# Out:
#       [QUOTE_DATE]  [UNDERLYING_LAST] [EXPIRE_DATE]   [DTE]  [STRIKE]  \
# 0       2023-01-03             380.82    2023-01-03     0.0     310.0
# 1       2023-01-03             380.82    2023-01-03     0.0     320.0
# 2       2023-01-03             380.82    2023-01-03     0.0     324.0
# 3       2023-01-03             380.82    2023-01-03     0.0     325.0
# 4       2023-01-03             380.82    2023-01-03     0.0     326.0
# ...            ...                ...           ...     ...       ...
# 78916   2023-01-31             406.44    2025-12-19  1053.0     630.0
# 78917   2023-01-31             406.44    2025-12-19  1053.0     635.0
# 78918   2023-01-31             406.44    2025-12-19  1053.0     640.0
# 78919   2023-01-31             406.44    2025-12-19  1053.0     645.0
# 78920   2023-01-31             406.44    2025-12-19  1053.0     650.0
#
#        [P_BID]  [P_ASK]   [P_SIZE]  [P_LAST]  [P_DELTA]  [P_GAMMA]  [P_VEGA]  \
# ...

# %%
# import main

# main.df
